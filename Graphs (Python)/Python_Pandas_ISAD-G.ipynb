# %% [markdown]
# # ISAD(G): General International Standard Archival Description - Second edition
# ## CBPS - Sub-Committee on Descriptive Standards
# ## 1 September 2011
#
# https://www.ica.org/en/isadg-general-international-standard-archival-description-second-edition

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/tutorials.html

# %%
import pandas as pd
data = pd.read_csv('https://raw.githubusercontent.com/stephen-rowan/Jupyter_Notebooks/master/ISAD-G/ISAD-G.csv')

# %%
data
# Out:
#     ISAD_G_Level_ID                        ISAD_G_Area  \
# 0               1.1            Identity Statement Area
# 1               1.2            Identity Statement Area
# 2               1.3            Identity Statement Area
# 3               1.4            Identity Statement Area
# 4               1.5            Identity Statement Area
# 5               2.1                       Context Area
# 6               2.2                       Context Area
# 7               2.3                       Context Area
# 8               2.4                       Context Area
# 9               3.1         Content and Structure Area
# 10              3.2         Content and Structure Area
# 11              3.3         Content and Structure Area
# 12              3.4         Content and Structure Area
# 13              4.1  Conditions of Access and Use Area
# 14              4.2  Conditions of Access and Use Area
# 15              4.3  Conditions of Access and Use Area
# ...

# %%
data.head()
# Out:
#    ISAD_G_Level_ID              ISAD_G_Area  \
# 0              1.1  Identity Statement Area
# 1              1.2  Identity Statement Area
# 2              1.3  Identity Statement Area
# 3              1.4  Identity Statement Area
# 4              1.5  Identity Statement Area
#
#                                         Element      Fonds   SubFonds  \
# 0                                Reference code  mandatory  mandatory
# 1                                         Title  mandatory  mandatory
# 2                                         Dates  mandatory  mandatory
# 3                          Level of description  mandatory  mandatory
# 4  Extent and medium of the unit of description  mandatory  mandatory
#
#       Series       File       Item
# 0  mandatory  mandatory  mandatory
# 1  mandatory  mandatory  mandatory
# 2  mandatory  mandatory  mandatory
# 3  mandatory  mandatory  mandatory
# 4  mandatory  mandatory  mandatory

# %%
#data["ISAD_G_Level_ID"]
data["Element"]
# Out:
# 0                                        Reference code
# 1                                                 Title
# 2                                                 Dates
# 3                                  Level of description
# 4          Extent and medium of the unit of description
# 5                                       Name of Creator
# 6                   Administrative/biographical history
# 7                                      Archival history
# 8           Immediate source of acquisition or transfer
# 9                                     Scope and content
# 10    Appraisal, destruction and scheduling information
# 11                                             Accruals
# 12                                System of Arrangement
# 13                          Conditions governing access
# 14                    Conditions governing reproduction
# 15                         Language/scripts of material
# 16    Physical characteristics and technical require...
# ...

# %%
data[data['Fonds'].str.match('mandatory')]
# Out:
#    ISAD_G_Level_ID              ISAD_G_Area  \
# 0              1.1  Identity Statement Area
# 1              1.2  Identity Statement Area
# 2              1.3  Identity Statement Area
# 3              1.4  Identity Statement Area
# 4              1.5  Identity Statement Area
# 5              2.1             Context Area
#
#                                         Element      Fonds   SubFonds  \
# 0                                Reference code  mandatory  mandatory
# 1                                         Title  mandatory  mandatory
# 2                                         Dates  mandatory  mandatory
# 3                          Level of description  mandatory  mandatory
# 4  Extent and medium of the unit of description  mandatory  mandatory
# 5                               Name of Creator  mandatory  mandatory
#
#       Series       File       Item
# 0  mandatory  mandatory  mandatory
# 1  mandatory  mandatory  mandatory
# 2  mandatory  mandatory  mandatory
# ...

# %%
data[:2]
# Out:
#    ISAD_G_Level_ID              ISAD_G_Area         Element      Fonds  \
# 0              1.1  Identity Statement Area  Reference code  mandatory
# 1              1.2  Identity Statement Area           Title  mandatory
#
#     SubFonds     Series       File       Item
# 0  mandatory  mandatory  mandatory  mandatory
# 1  mandatory  mandatory  mandatory  mandatory

# %%
data['Element'][:5]
# Out:
# 0                                  Reference code
# 1                                           Title
# 2                                           Dates
# 3                            Level of description
# 4    Extent and medium of the unit of description
# Name: Element, dtype: object

# %%
data[['Element', 'Fonds']][:5]
# Out:
#                                         Element      Fonds
# 0                                Reference code  mandatory
# 1                                         Title  mandatory
# 2                                         Dates  mandatory
# 3                          Level of description  mandatory
# 4  Extent and medium of the unit of description  mandatory

# %%
data['Fonds'].value_counts()
# Out:
# optional     20
# mandatory     6
# Name: Fonds, dtype: int64

# %%
ISAD_G_Area_counts = data['ISAD_G_Area'].value_counts()

# %%
ISAD_G_Area_counts
# Out:
# Conditions of Access and Use Area    5
# Identity Statement Area              5
# Content and Structure Area           4
# Context Area                         4
# Allied Materials Area                4
# Description control area             3
# Notes Area                           1
# Name: ISAD_G_Area, dtype: int64

# %%
data.index
# Out:
# RangeIndex(start=0, stop=26, step=1)
