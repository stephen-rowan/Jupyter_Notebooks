# %% [markdown]
# # AfterAlice Data
#
# <br>
# <font size=3>
#
# This [jupyter workbook](https://jupyter.org/) uses the [R statistical language](https://en.wikipedia.org/wiki/R_(programming_language)) to extract data from the [AfterAlice website](http://theafteraliceproject.org/) using Omeka's [JSON API](https://omeka.org/classic/docs/Technical/Output_Formats/).
#
# </font>

# %% [markdown]
# ## Load packages and the data
#
# Packages used below:
#
# * jsonlite for parsing JSON
# * purrr (A functional programming toolkit for R)
# * listviewer for doing recon on awkward lists
# * tibble and dplyr for forming and manipulating data frames

# %%
library(jsonlite)

# %%
library(purrr)
# Out:
# Attaching package: ‘purrr’
#
# The following object is masked from ‘package:jsonlite’:
#
#     flatten

# %%
install.packages("listviewer")
# Out:
# also installing the dependency ‘htmlwidgets’
#
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library(listviewer)

# %%
library(tibble)

# %%
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:purrr’:
#
#     contains, order_by
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# # Retrieving the data
# <br>
# <font size=3>
#
# The JSON data at http://theafteraliceproject.org/api/collections is retreived using a library function `jsonlite::fromJSON` and placed in the dataframe called ``collections_raw`` ...
#
# </font>

# %%
collections_raw <- jsonlite::fromJSON("http://theafteraliceproject.org/api/collections", simplifyVector = FALSE)

# %% [markdown]
# # Examining the data
# <br>
# <font size=3>
# When you first import the JSON - the structure will be unfamiliar so it is necessary to explore.
#
# A more readable format of the JSON can be viewed on the AfterAlice website at http://theafteraliceproject.org/api/collections?pretty_print .
#
#
# To view the structure of the first collection in the JSON we use the `str` command on the dataframe `collections_raw` ...
# </font>

# %%
str(collections_raw[[1]])
# Out:
# List of 10
#  $ id                : int 1
#  $ url               : chr "http://theafteraliceproject.org/api/collections/1"
#  $ public            : logi TRUE
#  $ featured          : logi TRUE
#  $ added             : chr "2016-10-03T17:58:21+00:00"
#  $ modified          : chr "2017-01-14T10:19:17+00:00"
#  $ owner             :List of 3
#   ..$ id      : int 1
#   ..$ url     : chr "http://theafteraliceproject.org/api/users/1"
#   ..$ resource: chr "users"
#  $ items             :List of 3
#   ..$ count   : int 4044
#   ..$ url     : chr "http://theafteraliceproject.org/api/items?collection=1"
#   ..$ resource: chr "items"
#  $ element_texts     :List of 3
#   ..$ :List of 3
#   .. ..$ text       : chr "Hebden Bridge"
#   .. ..$ element_set:List of 4
#   .. .. ..$ id      : int 1
#   .. .. ..$ url     : chr "http://theafteraliceproject.org/api/element_sets/1"
#   .. .. ..$ name    : chr "Dublin Core"
#   .. .. ..$ resource: chr "element_sets"
#   .. ..$ element    :List of 4
#   .. .. ..$ id      : int 50
#   .. .. ..$ url     : chr "http://theafteraliceproject.org/api/elements/50"
#   .. .. ..$ name    : chr "Title"
#   .. .. ..$ resource: chr "elements"
#   ..$ :List of 3
#   .. ..$ text       : chr "<span>Hebden Bridge is a market town which forms part of Hebden Royd in West Yorkshire, England. It is in the Upper Calder Vall"| __truncated__
#   .. ..$ element_set:List of 4
#   .. .. ..$ id      : int 1
#   .. .. ..$ url     : chr "http://theafteraliceproject.org/api/element_sets/1"
#   .. .. ..$ name    : chr "Dublin Core"
#   .. .. ..$ resource: chr "element_sets"
#   .. ..$ element    :List of 4
#   .. .. ..$ id      : int 41
#   .. .. ..$ url     : chr "http://theafteraliceproject.org/api/elements/41"
#   .. .. ..$ name    : chr "Description"
#   .. .. ..$ resource: chr "elements"
#   ..$ :List of 3
#   .. ..$ text       : chr "<div class=\"_cgc\">\n<div class=\"r-iv66X8zOlhmU\">\n<div class=\"kno-rdesc r-iQ5ocSYwNDPc\"><span>Hebden Bridge is a market t"| __truncated__
#   .. ..$ element_set:List of 4
#   .. .. ..$ id      : int 1
#   .. .. ..$ url     : chr "http://theafteraliceproject.org/api/element_sets/1"
#   .. .. ..$ name    : chr "Dublin Core"
#   .. .. ..$ resource: chr "element_sets"
#   .. ..$ element    :List of 4
#   .. .. ..$ id      : int 49
#   .. .. ..$ url     : chr "http://theafteraliceproject.org/api/elements/49"
#   .. .. ..$ name    : chr "Subject"
#   .. .. ..$ resource: chr "elements"
#  $ extended_resources:List of 1
#   ..$ comments:List of 3
#   .. ..$ count   : int 0
#   .. ..$ resource: chr "comments"
#   .. ..$ url     : chr "http://theafteraliceproject.org/api/comments?record_type=Collection&record_id=1"

# %% [markdown]
# <br>
# <font size=3>
# This seems unwieldy at first - but upon examination reveals a hierarchical structure.
#
# We can extract the names of elements at the top most level by querying the ``collections_raw`` data frame as follows ...
#
# </font>

# %%
top_level_names <- names(collections_raw[[1]])
top_level_names
# Out:
#  [1] "id"                 "url"                "public"
#  [4] "featured"           "added"              "modified"
#  [7] "owner"              "items"              "element_texts"
# [10] "extended_resources"

# %% [markdown]
# # Element text data
# <br>
# <font size=3>
# If we pull out just the `element_texts` as `element_text_data` - we can see the 3 lists of metadata that comprise the `element_texts` of collections ...
# </font>

# %%
element_text_data <- collections_raw[[1]][["element_texts"]]
element_text_data
# Out:
# [[1]]
# [[1]]$text
# [1] "Hebden Bridge"
#
# [[1]]$element_set
# [[1]]$element_set$id
# [1] 1
#
# [[1]]$element_set$url
# [1] "http://theafteraliceproject.org/api/element_sets/1"
#
# [[1]]$element_set$name
# [1] "Dublin Core"
#
# [[1]]$element_set$resource
# [1] "element_sets"
#
#
# [[1]]$element
# [[1]]$element$id
# [1] 50
#
# [[1]]$element$url
# [1] "http://theafteraliceproject.org/api/elements/50"
#
# [[1]]$element$name
# [1] "Title"
#
# [[1]]$element$resource
# [1] "elements"
#
#
#
# [[2]]
# [[2]]$text
# [1] "<span>Hebden Bridge is a market town which forms part of Hebden Royd in West Yorkshire, England. It is in the Upper Calder Valley, 8 miles west of Halifax and 14 miles north-east of Rochdale, at the confluence of the River Calder and the Hebden Water.</span><span><a class=\"fl q _KCd _tWc\" href=\"http://en.wikipedia.org/wiki/Hebden_Bridge\">Wikipedia</a></span><br /><br />"
#
# [[2]]$element_set
# [[2]]$element_set$id
# [1] 1
#
# [[2]]$element_set$url
# [1] "http://theafteraliceproject.org/api/element_sets/1"
#
# [[2]]$element_set$name
# [1] "Dublin Core"
#
# [[2]]$element_set$resource
# [1] "element_sets"
#
#
# [[2]]$element
# [[2]]$element$id
# [1] 41
#
# [[2]]$element$url
# [1] "http://theafteraliceproject.org/api/elements/41"
#
# [[2]]$element$name
# [1] "Description"
#
# [[2]]$element$resource
# [1] "elements"
#
#
#
# [[3]]
# [[3]]$text
# [1] "<div class=\"_cgc\">\n<div class=\"r-iv66X8zOlhmU\">\n<div class=\"kno-rdesc r-iQ5ocSYwNDPc\"><span>Hebden Bridge is a market town which forms part of Hebden Royd in West Yorkshire, England. It is in the Upper Calder Valley, 8 miles (13 km) west of Halifax and 14 miles (21 km) north-east of Rochdale, at the confluence of the River Calder and the Hebden Water. In 2004, the Calder Valley ward, covering Hebden Bridge, Old Town, and part of Todmorden, had a population of 11,549; the town itself has a population of approximately 4,500. Source: Wikipedia</span></div>\n</div>\n</div>"
#
# [[3]]$element_set
# [[3]]$element_set$id
# [1] 1
#
# [[3]]$element_set$url
# [1] "http://theafteraliceproject.org/api/element_sets/1"
#
# [[3]]$element_set$name
# [1] "Dublin Core"
#
# [[3]]$element_set$resource
# [1] "element_sets"
#
#
# [[3]]$element
# [[3]]$element$id
# [1] 49
#
# [[3]]$element$url
# [1] "http://theafteraliceproject.org/api/elements/49"
#
# [[3]]$element$name
# [1] "Subject"
#
# [[3]]$element$resource
# [1] "elements"

# %%
for (i in 1:3){
    print(collections_raw[[1]]$element_texts[[i]]$element$name)
       }
# Out:
# [1] "Title"
# [1] "Description"
# [1] "Subject"

# %%
a <- collections_raw[[1]][["element_texts"]][[2]][["text"]]
a
# Out:
# [1] "<span>Hebden Bridge is a market town which forms part of Hebden Royd in West Yorkshire, England. It is in the Upper Calder Valley, 8 miles west of Halifax and 14 miles north-east of Rochdale, at the confluence of the River Calder and the Hebden Water.</span><span><a class=\"fl q _KCd _tWc\" href=\"http://en.wikipedia.org/wiki/Hebden_Bridge\">Wikipedia</a></span><br /><br />"

# %%
b <- collections_raw[[1]][["element_texts"]][[1]][["text"]]
b


c <- collections_raw[[1]][["element_texts"]][[1]][["element"]][["name"]]
c
# Out:
# [1] "Hebden Bridge"
# [1] "Title"

# %%
collection_title <-0

for (i in 1:90){
    collection_title[i] <-collections_raw[[i]][["element_texts"]][[1]][["text"]]
       }
collection_title
# Out:
#  [1] "Hebden Bridge"       "Heptonstall"         "Todmorden"
#  [4] "Cornholme"           "Sowerby Bridge"      "Walsden"
#  [7] "Mytholmroyd"         "Luddendenfoot"       "Lumbutts"
# [10] "Mankinholes"         "Bradford"            "Wyke"
# [13] "Haworth"             "Pecket Well"         "Settle"
# [16] "Barnsley"            "Whitby"              "Robin Hood's Bay"
# [19] "Goathland"           "Ripon"               "Addingham"
# [22] "Runswick Bay"        "Silsden"             "Sandsend"
# [25] "Saltburn-by-the-Sea" "Bridlington"         "Heckmondwike"
# [28] "Grassington"         "Keighley"            "Denholme"
# [31] "Oxenhope"            "Halifax"             "Old Town"
# [34] "Otley"               "Wetherby"            "Ruswarp"
# [37] "Staithes"            "Malton"              "Skipton"
# [40] "Malham"              "Filey"               "Ilkley"
# [43] "Grosmont"            "Pickering"           "Shipley"
# [46] "Sleights"            "Cragg Vale"          "Blackshaw Head"
# [49] "Sandbed"             "Saltaire"            "Ingleton"
# [52] "Chapel-le-Dale"      "Bingley"             "Erringden"
# [55] "Charlestown"         "Birstall"            "Colden"
# [58] "Eastwood"            "Luddenden"           "Easington"
# [61] "Pateley Bridge"      "Huddersfield"        "Sowerby"
# [64] "Widdop"              "Oakworth"            "Elland"
# [67] "Harden"              "Cullingworth"        "Cleckheaton"
# [70] "Hipperholme"         "Bolton Abbey"        "Harrogate"
# [73] "West Bretton"        "West Vale"           "Wakefield"
# [76] "Ossett"              "Rotherham"           "Leeds"
# [79] "Pontefract"          "York"                "London"
# [82] "Gomersal"            "Holmfirth"           "Ripponden"
# [85] "Batley"              "Doncaster"           "Stanbury"
# [88] "Riddlesden"          "Midgley"             "Wainstalls"

# %%
collection_description <-0

for (i in 1:90){
    collection_description[i] <- collections_raw[[i]][["element_texts"]][[2]][["text"]]
       }
collection_description
# Out:
#  [1] "<span>Hebden Bridge is a market town which forms part of Hebden Royd in West Yorkshire, England. It is in the Upper Calder Valley, 8 miles west of Halifax and 14 miles north-east of Rochdale, at the confluence of the River Calder and the Hebden Water.</span><span><a class=\"fl q _KCd _tWc\" href=\"http://en.wikipedia.org/wiki/Hebden_Bridge\">Wikipedia</a></span><br /><br />"
#  [2] "<span>Heptonstall is a small village and civil parish within the Calderdale borough of West Yorkshire, England, historically part of the West Riding of Yorkshire.</span><span><a class=\"fl q _KCd _tWc\" href=\"http://en.wikipedia.org/wiki/Heptonstall\">Wikipedia</a></span><br /><br />"
#  [3] "<span>Todmorden is a market town and civil parish in the Upper Calder Valley in Calderdale, West Yorkshire, England. It is 17 miles from Manchester and in 2011 had a population of 15,481.</span><span><a class=\"fl q _KCd _tWc\" href=\"http://en.wikipedia.org/wiki/Todmorden\">Wikipedia</a></span><br /><br />"
#  [4] "<span>Cornholme is a village within the Metropolitan Borough of Calderdale, in West Yorkshire, England. It lies at the edge of Calderdale, on the boundary with Lancashire, and in the narrow Calder Valley about 2.5 miles northwest of Todmorden.</span><span><a class=\"fl q _KCd _tWc\" href=\"http://en.wikipedia.org/wiki/Cornholme\">Wikipedia</a></span><br /><br />"
#  [5] "Sowerby Bridge is a market town in the Upper Calder Valley in Calderdale in West Yorkshire, England. The Calderdale Council ward population at the 2011 census was 11,703. <em>Source: Wikipedia</em>"
#  [6] "<span>Walsden is a large village in the civil parish of Todmorden in the Metropolitan Borough of Calderdale, West Yorkshire, England, though historically in Lancashire and close to the modern boundary with Greater Manchester.</span><span><a class=\"fl q _KCd _tWc\" href=\"http://en.wikipedia.org/wiki/Walsden\">Wikipedia</a></span><br /><br />"
#  [7] "<span>Mytholmroyd is a large village in Hebden Bridge, West Yorkshire, England, 1 mile east of Hebden Bridge and 7 miles west of Halifax.</span><span><a class=\"fl q _KCd _tWc\" href=\"http://en.wikipedia.org/wiki/Mytholmroyd\">Wikipedia</a></span>"
#  [8] "<span>Luddendenfoot or Luddenden Foot is a community in Calderdale, West Yorkshire, England. The population of this Calderdale Ward at the 2011 Census was 10,653.</span><span><a class=\"fl q _KCd _tWc\" href=\"http://en.wikipedia.org/wiki/Luddendenfoot\">Wikipedia</a></span><br /><br />"
#  [9] "Images taken in Lumbutts village and it's immediate surrounds."
# [10] "<span>Mankinholes is a hamlet in the Metropolitan Borough of Calderdale, in West Yorkshire, England. It is situated in the Pennines and the nearest town is Todmorden in Yorkshire. The hamlet is part of Calder Ward in Calderdale Parish Council.</span><span><a class=\"fl q _KCd _tWc\" href=\"http://en.wikipedia.org/wiki/Mankinholes\">Wikipedia</a></span><br /><br />"
# [11] "<span>Bradford /ˈbrædfərd/ is in the Metropolitan Borough of the City of Bradford in West Yorkshire, England, in the foothills of the Pennines 8.6 miles west of Leeds, and 16 miles northwest of Wakefield.</span><span><a class=\"fl q _KCd _tWc\" href=\"http://en.wikipedia.org/wiki/Bradford\">Wikipedia</a></span><br /><br />"
# [12] "<span>Wyke is a Ward in Bradford Metropolitan District in the county of West Yorkshire, England, named after the village of Wyke. The population taken at the 2011 Census was 14,958.</span><span><a class=\"fl q _KCd _tWc\" href=\"http://en.wikipedia.org/wiki/
# [86] "<div class=\"_cgc kno-fb-ctx\">\n<div class=\"r-iukVi_0RSK_g\">\n<div class=\"kno-rdesc r-ibHxfRZDqHsk\"><span>Doncaster, is a large market town in South Yorkshire, England. Together with its surrounding suburbs and settlements, the town forms part of the Metropolitan Borough of Doncaster, which had a mid-2015 est. population of 304,800.</span><span><span> </span><a class=\"fl q _KCd _tWc\" href=\"https://en.wikipedia.org/wiki/Doncaster\">Wikipedia</a></span></div>\n</div>\n</div>"
# [87] "<div class=\"_cgc kno-fb-ctx\">\n<div class=\"r-iFOM98_OtM94\">\n<div class=\"kno-rdesc r-i534Ht1NQw10\"><span>Stanbury is a village in the Haworth, Cross Roads and Stanbury civil parish, and in the metropolitan borough of the City of Bradford in West Yorkshire, England.</span><span><span> </span><a class=\"q _KCd _tWc fl\" href=\"https://en.wikipedia.org/wiki/Stanbury\">Wikipedia</a></span></div>\n</div>\n</div>"
# [88] "<div class=\"_cgc kno-fb-ctx\">\n<div class=\"r-i2VThyduAMfg\">\n<div class=\"kno-rdesc r-iBvL3a67X99c\"><span>Riddlesden is a suburb of Keighley in the county of West Yorkshire, England and on the Leeds and Liverpool Canal. Most of Riddlesden is made up of hills and steep land, like farms and even woodland.</span><span><span> </span><a class=\"q _KCd _tWc fl\" href=\"http://en.wikipedia.org/wiki/Riddlesden\">Wikipedia</a></span></div>\n</div>\n</div>"
# [89] "Midgley is a hill-top village in Calderdale, West Yorkshire, England. It is situated approximately 12 miles (20 km) east from Burnley and 4 miles (6 km) west-north-west of Halifax town centres, and just north of the A646 road. Nearby villages are Mytholmroyd 1 mile (1.6 km) to the west-south-west, and Hebden Bridge 2.5 miles (4.0 km) to the west-north-west. Wikipedia"
# [90] "<strong><strong></strong></strong>\n<div class=\"_cgc kno-fb-ctx\">\n<div class=\"r-iZrIQqDOIaUY\">\n<div class=\"kno-rdesc r-iDcnKSjzcgT8\"><span>Wainstalls is a district of Halifax, in West Yorkshire, England. The area is rural and much of the area is farmland. Wainstalls is in the HX postcode area and in the HX2 postcode district and the Luddendenfoot ward of Calderdale Council.</span><span><span> </span><a class=\"q _KCd _tWc fl\" href=\"https://en.wikipedia.org/wiki/Wainstalls\">Wikipedia</a></span></div>\n</div>\n</div>"

# %% [markdown]
# ## Voyage of discovery

# %%
for (i in 1:3){
    print(collections_raw[[1]][["element_texts"]][[i]]$element$name)
       }
# Out:
# [1] "Title"
# [1] "Description"
# [1] "Subject"

# %%
#initialise an empty object and then assign the value by indexing

cnames <-0

for (i in 1:3){
    cnames[i] <-(collections_raw[[1]][["element_texts"]][[i]]$element$name)
       }
cnames
# Out:
# [1] "Title"       "Description" "Subject"

# %%
for (i in 1:3){
    print(collections_raw[[1]][["element_texts"]][[i]]$text)
       }
# Out:
# [1] "Hebden Bridge"
# [1] "<span>Hebden Bridge is a market town which forms part of Hebden Royd in West Yorkshire, England. It is in the Upper Calder Valley, 8 miles west of Halifax and 14 miles north-east of Rochdale, at the confluence of the River Calder and the Hebden Water.</span><span><a class=\"fl q _KCd _tWc\" href=\"http://en.wikipedia.org/wiki/Hebden_Bridge\">Wikipedia</a></span><br /><br />"
# [1] "<div class=\"_cgc\">\n<div class=\"r-iv66X8zOlhmU\">\n<div class=\"kno-rdesc r-iQ5ocSYwNDPc\"><span>Hebden Bridge is a market town which forms part of Hebden Royd in West Yorkshire, England. It is in the Upper Calder Valley, 8 miles (13 km) west of Halifax and 14 miles (21 km) north-east of Rochdale, at the confluence of the River Calder and the Hebden Water. In 2004, the Calder Valley ward, covering Hebden Bridge, Old Town, and part of Todmorden, had a population of 11,549; the town itself has a population of approximately 4,500. Source: Wikipedia</span></div>\n</div>\n</div>"

# %%
ctext <-0

for (i in 1:3){
    ctext[i] <-(collections_raw[[2]][["element_texts"]][[i]]$text)
       }
ctext
# Out:
# [1] "Heptonstall"
# [2] "<span>Heptonstall is a small village and civil parish within the Calderdale borough of West Yorkshire, England, historically part of the West Riding of Yorkshire.</span><span><a class=\"fl q _KCd _tWc\" href=\"http://en.wikipedia.org/wiki/Heptonstall\">Wikipedia</a></span><br /><br />"
# [3] "<div class=\"_cgc\">\n<div class=\"r-iUhkTHZShunI\">\n<div class=\"kno-rdesc r-i5RQfDurzkj4\"><span>Heptonstall is a small village and civil parish within the Calderdale borough of West Yorkshire, England, historically part of the West Riding of Yorkshire. The population of Heptonstall, including the hamlets of Colden and Slack Top, is 1,448, increasing to 1,470 at the 2011 Census. The town of Hebden Bridge lies directly to the south-east. Although Heptonstall is part of Hebden Bridge as a post town, it is not within the Hebden Royd town boundaries. The village is on the route of the Calderdale Way, a 50-mile (80 km) circular walk around the hills and valleys of Calderdale. <em>Source: Wikipedia</em></span></div>\n</div>\n</div>"

# %%
# Construct matrix
collection_matrix <- matrix(c(ctext), ncol = 3)
collection_matrix
# Out:
#      [,1]
# [1,] Heptonstall
#      [,2]
# [1,] <span>Heptonstall is a small village and civil parish within the Calderdale borough of West Yorkshire, England, historically part of the West Riding of Yorkshire.</span><span><a class="fl q _KCd _tWc" href="http://en.wikipedia.org/wiki/Heptonstall">Wikipedia</a></span><br /><br />
#      [,3]
# [1,] <div class="_cgc">\n<div class="r-iUhkTHZShunI">\n<div class="kno-rdesc r-i5RQfDurzkj4"><span>Heptonstall is a small village and civil parish within the Calderdale borough of West Yorkshire, England, historically part of the West Riding of Yorkshire. The population of Heptonstall, including the hamlets of Colden and Slack Top, is 1,448, increasing to 1,470 at the 2011 Census. The town of Hebden Bridge lies directly to the south-east. Although Heptonstall is part of Hebden Bridge as a post town, it is not within the Hebden Royd town boundaries. The village is on the route of the Calderdale Way, a 50-mile (80 km) circular walk around the hills and valleys of Calderdale. <em>Source: Wikipedia</em></span></div>\n</div>\n</div>

# %%
# Name the columns with region
colnames(collection_matrix) <- cnames

# %%
collection_matrix
# Out:
#      Title
# [1,] Heptonstall
#      Description
# [1,] <span>Heptonstall is a small village and civil parish within the Calderdale borough of West Yorkshire, England, historically part of the West Riding of Yorkshire.</span><span><a class="fl q _KCd _tWc" href="http://en.wikipedia.org/wiki/Heptonstall">Wikipedia</a></span><br /><br />
#      Subject
# [1,] <div class="_cgc">\n<div class="r-iUhkTHZShunI">\n<div class="kno-rdesc r-i5RQfDurzkj4"><span>Heptonstall is a small village and civil parish within the Calderdale borough of West Yorkshire, England, historically part of the West Riding of Yorkshire. The population of Heptonstall, including the hamlets of Colden and Slack Top, is 1,448, increasing to 1,470 at the 2011 Census. The town of Hebden Bridge lies directly to the south-east. Although Heptonstall is part of Hebden Bridge as a post town, it is not within the Hebden Royd town boundaries. The village is on the route of the Calderdale Way, a 50-mile (80 km) circular walk around the hills and valleys of Calderdale. <em>Source: Wikipedia</em></span></div>\n</div>\n</div>

# %%
collection_title <-0
collection_description <-0

for (i in 1:90){
    collection_title[i] <-collections_raw[[i]][["element_texts"]][[1]][["text"]]
    collection_description[i] <- collections_raw[[i]][["element_texts"]][[2]][["text"]]
       }
collection_title
collection_description
# Out:
#  [1] "Hebden Bridge"       "Heptonstall"         "Todmorden"
#  [4] "Cornholme"           "Sowerby Bridge"      "Walsden"
#  [7] "Mytholmroyd"         "Luddendenfoot"       "Lumbutts"
# [10] "Mankinholes"         "Bradford"            "Wyke"
# [13] "Haworth"             "Pecket Well"         "Settle"
# [16] "Barnsley"            "Whitby"              "Robin Hood's Bay"
# [19] "Goathland"           "Ripon"               "Addingham"
# [22] "Runswick Bay"        "Silsden"             "Sandsend"
# [25] "Saltburn-by-the-Sea" "Bridlington"         "Heckmondwike"
# [28] "Grassington"         "Keighley"            "Denholme"
# [31] "Oxenhope"            "Halifax"             "Old Town"
# [34] "Otley"               "Wetherby"            "Ruswarp"
# [37] "Staithes"            "Malton"              "Skipton"
# [40] "Malham"              "Filey"               "Ilkley"
# [43] "Grosmont"            "Pickering"           "Shipley"
# [46] "Sleights"            "Cragg Vale"          "Blackshaw Head"
# [49] "Sandbed"             "Saltaire"            "Ingleton"
# [52] "Chapel-le-Dale"      "Bingley"             "Erringden"
# [55] "Charlestown"         "Birstall"            "Colden"
# [58] "Eastwood"            "Luddenden"           "Easington"
# [61] "Pateley Bridge"      "Huddersfield"        "Sowerby"
# [64] "Widdop"              "Oakworth"            "Elland"
# [67] "Harden"              "Cullingworth"        "Cleckheaton"
# [70] "Hipperholme"         "Bolton Abbey"        "Harrogate"
# [73] "West Bretton"        "West Vale"           "Wakefield"
# [76] "Ossett"              "Rotherham"           "Leeds"
# [79] "Pontefract"          "York"                "London"
# [82] "Gomersal"            "Holmfirth"           "Ripponden"
# [85] "Batley"              "Doncaster"           "Stanbury"
# [88] "Riddlesden"          "Midgley"             "Wainstalls"
#  [1] "<span>Hebden Bridge is a market town which forms part of Hebden Royd in West Yorkshire, England. It is in the Upper Calder Valley, 8 miles west of Halifax and 14 miles north-east of Rochdale, at the confluence of the River Calder and the Hebden Water.</span><span><a class=\"fl q _KCd _tWc\" href=\"http://en.wikipedia.org/wiki/Hebden_Bridge\">Wikipedia</a></span><br /><br />"
#  [2] "<span>Heptonstall is a small village and civil parish within the Calderdale borough of West Yorkshire, England, historically part of the West Riding of Yorkshire.</span><span><a class=\"fl q _KCd _tWc\" href=\"http://en.wikipedia.org/wiki/Heptonstall\">Wikipedia</a></span><br /><br />"
#  [3] "<span>Todmorden is a market town and civil parish in the Upper Calder Valley in Calderdale, West Yorkshire, England. It is 17 miles from Manchester and in 2011 had a population of 15,481.</span><span><a class=\"fl q _KCd _tWc\" href=\"http://en.wikipedia.org/wiki/Todmorden\">Wikipedia</a></span><br /><br />"
#  [4] "<span>Cornholme is a village within the Metropolitan Borough of Calderdale, in West Yorkshire, England. It lies at the edge of Calderdale, on the boundary with Lancashire, and in the narrow Calder Valley about 2.5 miles northwest of Todmorden.</span><span><a class=\"fl q _KCd _tWc\" href=\"http://en.wikipedia.org/wiki/
</span><span><a class=\"fl q _KCd _tWc\" href=\"http://en.wikipedia.org/wiki/Goathland\">Wikipedia</a></span><br /><br />"
# ...
# [84] "<div class=\"_cgc kno-fb-ctx\">\n<div class=\"r-ivzFbPEgoQ1A\">\n<div class=\"kno-rdesc r-iZ0WD_LpANHg\"><span>Ripponden is a village and civil parish on the River Ryburn near Halifax in West Yorkshire, England. Historically it was part of the West Riding of Yorkshire. Its population was 6,412 at the time of the 2001 Census, and 7,421 in 2011.</span><span><a class=\"fl q _KCd _tWc\" href=\"http://en.wikipedia.org/wiki/Ripponden\">Wikipedia</a></span></div>\n</div>\n</div>"
# [85] "<div class=\"_cgc kno-fb-ctx\">\n<div class=\"r-iYOi4D1td5po\">\n<div class=\"kno-rdesc r-iTXaOYmmsbB0\"><span>Batley is a town in the Metropolitan Borough of Kirklees, West Yorkshire, England. It lies 7 miles south-east of Bradford, 7 miles south-west of Leeds and 1 mile north of Dewsbury, near the M62 motorway.</span><span><span> </span><a class=\"fl q _KCd _tWc\" href=\"https://en.wikipedia.org/wiki/Batley\">Wikipedia</a></span></div>\n</div>\n</div>"
# [86] "<div class=\"_cgc kno-fb-ctx\">\n<div class=\"r-iukVi_0RSK_g\">\n<div class=\"kno-rdesc r-ibHxfRZDqHsk\"><span>Doncaster, is a large market town in South Yorkshire, England. Together with its surrounding suburbs and settlements, the town forms part of the Metropolitan Borough of Doncaster, which had a mid-2015 est. population of 304,800.</span><span><span> </span><a class=\"fl q _KCd _tWc\" href=\"https://en.wikipedia.org/wiki/Doncaster\">Wikipedia</a></span></div>\n</div>\n</div>"
# [87] "<div class=\"_cgc kno-fb-ctx\">\n<div class=\"r-iFOM98_OtM94\">\n<div class=\"kno-rdesc r-i534Ht1NQw10\"><span>Stanbury is a village in the Haworth, Cross Roads and Stanbury civil parish, and in the metropolitan borough of the City of Bradford in West Yorkshire, England.</span><span><span> </span><a class=\"q _KCd _tWc fl\" href=\"https://en.wikipedia.org/wiki/Stanbury\">Wikipedia</a></span></div>\n</div>\n</div>"
# [88] "<div class=\"_cgc kno-fb-ctx\">\n<div class=\"r-i2VThyduAMfg\">\n<div class=\"kno-rdesc r-iBvL3a67X99c\"><span>Riddlesden is a suburb of Keighley in the county of West Yorkshire, England and on the Leeds and Liverpool Canal. Most of Riddlesden is made up of hills and steep land, like farms and even woodland.</span><span><span> </span><a class=\"q _KCd _tWc fl\" href=\"http://en.wikipedia.org/wiki/Riddlesden\">Wikipedia</a></span></div>\n</div>\n</div>"
# [89] "Midgley is a hill-top village in Calderdale, West Yorkshire, England. It is situated approximately 12 miles (20 km) east from Burnley and 4 miles (6 km) west-north-west of Halifax town centres, and just north of the A646 road. Nearby villages are Mytholmroyd 1 mile (1.6 km) to the west-south-west, and Hebden Bridge 2.5 miles (4.0 km) to the west-north-west. Wikipedia"
# [90] "<strong><strong></strong></strong>\n<div class=\"_cgc kno-fb-ctx\">\n<div class=\"r-iZrIQqDOIaUY\">\n<div class=\"kno-rdesc r-iDcnKSjzcgT8\"><span>Wainstalls is a district of Halifax, in West Yorkshire, England. The area is rural and much of the area is farmland. Wainstalls is in the HX postcode area and in the HX2 postcode district and the Luddendenfoot ward of Calderdale Council.</span><span><span> </span><a class=\"q _KCd _tWc fl\" href=\"https://en.wikipedia.org/wiki/Wainstalls\">Wikipedia</a></span></div>\n</div>\n</div>"

</span><span><a class="fl q _KCd _tWc" href="http://en.wikipedia.org/wiki/Holmfirth" data-ved="0ahUKEwiKpv_Ju7zRAhVDC8AKHcOvDMkQmhMIejAN">Wikipedia</a></span></div>\r\n</div>\r\n</div>
# [55,] <div class="_cgc kno-fb-ctx">\n<div class="r-ivzFbPEgoQ1A">\n<div class="kno-rdesc r-iZ0WD_LpANHg"><span>Ripponden is a village and civil parish on the River Ryburn near Halifax in West Yorkshire, England. Historically it was part of the West Riding of Yorkshire. Its population was 6,412 at the time of the 2001 Census, and 7,421 in 2011.</span><span><a class="fl q _KCd _tWc" href="http://en.wikipedia.org/wiki/Ripponden">Wikipedia</a></span></div>\n</div>\n</div>
# [56,] <div class="_cgc kno-fb-ctx">\n<div class="r-iYOi4D1td5po">\n<div class="kno-rdesc r-iTXaOYmmsbB0"><span>Batley is a town in the Metropolitan Borough of Kirklees, West Yorkshire, England. It lies 7 miles south-east of Bradford, 7 miles south-west of Leeds and 1 mile north of Dewsbury, near the M62 motorway.</span><span><span> </span><a class="fl q _KCd _tWc" href="https://en.wikipedia.org/wiki/Batley">Wikipedia</a></span></div>\n</div>\n</div>
# [57,] <div class="_cgc kno-fb-ctx">\n<div class="r-iukVi_0RSK_g">\n<div class="kno-rdesc r-ibHxfRZDqHsk"><span>Doncaster, is a large market town in South Yorkshire, England. Together with its surrounding suburbs and settlements, the town forms part of the Metropolitan Borough of Doncaster, which had a mid-2015 est. population of 304,800.</span><span><span> </span><a class="fl q _KCd _tWc" href="https://en.wikipedia.org/wiki/Doncaster">Wikipedia</a></span></div>\n</div>\n</div>
# [58,] <div class="_cgc kno-fb-ctx">\n<div class="r-iFOM98_OtM94">\n<div class="kno-rdesc r-i534Ht1NQw10"><span>Stanbury is a village in the Haworth, Cross Roads and Stanbury civil parish, and in the metropolitan borough of the City of Bradford in West Yorkshire, England.</span><span><span> </span><a class="q _KCd _tWc fl" href="https://en.wikipedia.org/wiki/Stanbury">Wikipedia</a></span></div>\n</div>\n</div>
# [59,] <div class="_cgc kno-fb-ctx">\n<div class="r-i2VThyduAMfg">\n<div class="kno-rdesc r-iBvL3a67X99c"><span>Riddlesden is a suburb of Keighley in the county of West Yorkshire, England and on the Leeds and Liverpool Canal. Most of Riddlesden is made up of hills and steep land, like farms and even woodland.</span><span><span> </span><a class="q _KCd _tWc fl" href="http://en.wikipedia.org/wiki/Riddlesden">Wikipedia</a></span></div>\n</div>\n</div>
# [60,] Midgley is a hill-top village in Calderdale, West Yorkshire, England. It is situated approximately 12 miles (20 km) east from Burnley and 4 miles (6 km) west-north-west of Halifax town centres, and just north of the A646 road. Nearby villages are Mytholmroyd 1 mile (1.6 km) to the west-south-west, and Hebden Bridge 2.5 miles (4.0 km) to the west-north-west. Wikipedia
# [61,] <strong><strong></strong></strong>\n<div class="_cgc kno-fb-ctx">\n<div class="r-iZrIQqDOIaUY">\n<div class="kno-rdesc r-iDcnKSjzcgT8"><span>Wainstalls is a district of Halifax, in West Yorkshire, England. The area is rural and much of the area is farmland. Wainstalls is in the HX postcode area and in the HX2 postcode district and the Luddendenfoot ward of Calderdale Council.</span><span><span> </span><a class="q _KCd _tWc fl" href="https://en.wikipedia.org/wiki/Wainstalls">Wikipedia</a></span></div>\n</div>\n</div>

# %%
dim (z_matrix)
# Out:
# [1] 90  2
